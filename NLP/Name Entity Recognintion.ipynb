# %% [markdown]
# Named Entity Recognition (NER)
#
# Named Entity Recognition (NER) is the process of identifying and classifying named entities (proper nouns) in text into predefined categories like person, organization, location, date, etc.
# Basic Concept
#
# Text: "Apple Inc. was founded by Steve Jobs in Cupertino, California on April 1, 1976"
#
# NER Output:
#
# Apple Inc.           → ORG (Organization)
#
# Steve Jobs          → PERSON (Person)
#
# Cupertino           → LOC (Location)
#
# California          → LOC (Location)
#
# April 1, 1976       → DATE (Date)

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\umamk\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\umamk\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# Perform word tokenization from sentence/corpus then extract the pos_tag then perform NER
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

sentence="Apple Inc. was founded by Steve Jobs in Cupertino, California on April 1, 1976"
words=word_tokenize(sentence)
words
# Out:
# ['Apple',
#  'Inc.',
#  'was',
#  'founded',
#  'by',
#  'Steve',
#  'Jobs',
#  'in',
#  'Cupertino',
#  ',',
#  'California',
#  'on',
#  'April',
#  '1',
#  ',',
#  '1976']

# %%
tag_elements=pos_tag(words)
tag_elements
# Out:
# [('Apple', 'NNP'),
#  ('Inc.', 'NNP'),
#  ('was', 'VBD'),
#  ('founded', 'VBN'),
#  ('by', 'IN'),
#  ('Steve', 'NNP'),
#  ('Jobs', 'NNP'),
#  ('in', 'IN'),
#  ('Cupertino', 'NNP'),
#  (',', ','),
#  ('California', 'NNP'),
#  ('on', 'IN'),
#  ('April', 'NNP'),
#  ('1', 'CD'),
#  (',', ','),
#  ('1976', 'CD')]

# %%
from nltk import ne_chunk
print(f"{ne_chunk(tag_elements)}\n")
ne_chunk(tag_elements).draw()
# Out:
# (S
#   (PERSON Apple/NNP)
#   (ORGANIZATION Inc./NNP)
#   was/VBD
#   founded/VBN
#   by/IN
#   (PERSON Steve/NNP Jobs/NNP)
#   in/IN
#   (GPE Cupertino/NNP)
#   ,/,
#   (GPE California/NNP)
#   on/IN
#   April/NNP
#   1/CD
#   ,/,
#   1976/CD)
